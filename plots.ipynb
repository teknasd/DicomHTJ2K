# %%
import pydicom
import matplotlib.pyplot as plt
def show_img(path):
    # Replace 'your_dicom_file.dcm' with the actual path to your DICOM file
    dicom_file_path = path
    
    # Read the DICOM file
    ds = pydicom.dcmread(dicom_file_path)
    
    # Get the pixel data
    pixel_data = ds.pixel_array
    
    # Display the image using Matplotlib
    plt.imshow(pixel_data, cmap=plt.cm.gray)
    plt.title('DICOM Image')
    plt.show()

# %%
show_img('./data/b8d52e80-c4e3-4a56-b528-286577f0e2d5.dcm')

# %%
show_img('./data/decompressed/b8d52e80-c4e3-4a56-b528-286577f0e2d5.dcm')
